# %% [markdown]
# # Simple Neural Network Music Genre Classification:

# %% [markdown]
# This notebook is dedicated to improving the test accuracy of the network presented in:
# https://www.kaggle.com/code/aasimahmed04/music-genre-classifier

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import MaxAbsScaler
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import librosa, IPython
import librosa.display as lplt

from sklearn.metrics import accuracy_score
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *
from keras import regularizers

import IPython.display as ipd
from IPython.display import Audio

# %% [markdown]
# ## 1. Load And Arrange The Data

# %% [markdown]
# The data set is included a .csv file with the extracted features:

# %%
df = pd.read_csv('features_30_sec.csv')

# %% [markdown]
# #### Check If The Data Is Balanced:

# %% [markdown]
# Class Balance:

# %%
df.label.value_counts().reset_index()
# Out:
#        label  count
# 0      blues    100
# 1  classical    100
# 2    country    100
# 3      disco    100
# 4     hiphop    100
# 5       jazz    100
# 6      metal    100
# 7        pop    100
# 8     reggae    100
# 9       rock    100

# %% [markdown]
# We have exactly 100 samples out of each class.

# %%
data = df.iloc[:,1:59];
labels_str = df['label'];

# %% [markdown]
# Map labels to numbers:

# %%
map_ = {
    "blues"     : 0,
    "classical" : 1,
    "country"   : 2,
    "disco"     : 3,
    "hiphop"    : 4,
    "jazz"      : 5,
    "metal"     : 6,
    "pop"       : 7,
    "reggae"    : 8,
    "rock"      : 9,
}

# %%
labels = np.array([map_[label_] for label_ in labels_str])

# %% [markdown]
# ## 2. Pre-Processing:

# %% [markdown]
# Scale the data to prevent feature imbalances:

# %%
data_scaler = MaxAbsScaler().fit(data);

# %%
scaled_data = data_scaler.transform(data);

# %% [markdown]
# Convert to float64 for better computation:

# %%
scaled_data.astype('float64', casting = 'same_kind');

# %% [markdown]
# Split the data to train and test:

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_data, labels, test_size=0.15,shuffle=True, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2,shuffle=True, random_state=1)

# %%
print("Train data size: ", X_train.shape);
print("Validation data size: ",X_val.shape);
print("Test data size: ", X_test.shape);
# Out:
# Train data size:  (680, 58)
# Validation data size:  (170, 58)
# Test data size:  (150, 58)

# %% [markdown]
# ## 4. Defining The Network:

# %%
#Creating a Neural Network
model = Sequential() 
  
model.add(Flatten(input_shape=(58,))) 
model.add(Dense(256, activation='relu')) 
model.add(BatchNormalization()) 
model.add(Dense(128, activation='relu')) 
model.add(Dropout(0.3))  
model.add(Dense(10, activation='softmax')) 

model.summary()
# Out:
# C:\Users\420\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 58)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          15,104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 50,314 (196.54 KB)
#  Trainable params: 49,802 (194.54 KB)
#  Non-trainable params: 512 (2.00 KB)

# %% [markdown]
# Compiling and fitting:

# %%
#Compiling & Fitting the Model
adam = keras.optimizers.Adam(learning_rate=1e-4)
model.compile(optimizer=adam, 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])
hist = model.fit(X_train, y_train, validation_data= (X_test, y_test),
                epochs=100,
                batch_size=32)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.1280 - loss: 2.6131 - val_accuracy: 0.1200 - val_loss: 2.3041
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2065 - loss: 2.2933 - val_accuracy: 0.1533 - val_loss: 2.2733
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2733 - loss: 2.0921 - val_accuracy: 0.1933 - val_loss: 2.2431
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8961 - loss: 0.3708 - val_accuracy: 0.7200 - val_loss: 0.8860
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9015 - loss: 0.3896 - val_accuracy: 0.7067 - val_loss: 0.8818
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9251 - loss: 0.3581 - val_accuracy: 0.7133 - val_loss: 0.8761
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8835 - loss: 0.3954 - val_accuracy: 0.7067 - val_loss: 0.8760
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9047 - loss: 0.3494 - val_accuracy: 0.7133 - val_loss: 0.8794
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9247 - loss: 0.3443 - val_accuracy: 0.7133 - val_loss: 0.8773
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8988 - loss: 0.3612 - val_accuracy: 0.7200 - val_loss: 0.8798
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8925 - loss: 0.4027 - val_accuracy: 0.7200 - val_loss: 0.8790
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9012 - loss: 0.3677 - val_accuracy: 0.7200 - val_loss: 0.8771
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9086 - loss: 0.3684 - val_accuracy: 0.7200 - val_loss: 0.8797
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9073 - loss: 0.3523 - val_accuracy: 0.7200 - val_loss: 0.8753
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9128 - loss: 0.3673 - val_accuracy: 0.7200 - val_loss: 0.8668
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9047 - loss: 0.3535 - val_accuracy: 0.7200 - val_loss: 0.8769
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9063 - loss: 0.3237 - val_accuracy: 0.7067 - val_loss: 0.8710
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9181 - loss: 0.3067 - val_accuracy: 0.7067 - val_loss: 0.8757
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9257 - loss: 0.3034 - val_accuracy: 0.7067 - val_loss: 0.8750
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9265 - loss: 0.3043 - val_accuracy: 0.7133 - val_loss: 0.8756
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9193 - loss: 0.2993 - val_accuracy: 0.7067 - val_loss: 0.8844
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9148 - loss: 0.3317 - val_accuracy: 0.7200 - val_loss: 0.8863
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9081 - loss: 0.3393 - val_accuracy: 0.7133 - val_loss: 0.8876
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9073 - loss: 0.3193 - val_accuracy: 0.7067 - val_loss: 0.8808

# %% [markdown]
# Test set:

# %%
y_predict = np.argmax(model.predict(X_test),axis=1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
acc = np.mean(y_predict == y_test)*100
print("test accuracy = %.2f"%acc, "%");
# Out:
# test accuracy = 70.67 %

# %% [markdown]
# Plot original scores:

# %%
fig, axs = plt.subplots(2, figsize=(10, 10))

#Accuracy
axs[0].plot(hist.history['accuracy'], label="train")
axs[0].plot(hist.history['val_loss'], label="test")
axs[0].set_ylabel("Accuracy")
axs[0].legend()
axs[0].set_title("Accuracy")
axs[0].grid()

#Error
axs[1].plot(hist.history["loss"], label="train") 
axs[1].plot(hist.history["val_loss"], label="test")     
axs[1].set_ylabel("Error") 
axs[1].legend() 
axs[1].set_title("Error") 
axs[1].grid()  
    
plt.show()

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_predict);

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues", values_format="d")

plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Improving The Network:

# %%
#Creating a Neural Network
model = Sequential() 
  
model.add(Flatten(input_shape=(58,))) 
model.add(Dense(256,kernel_regularizer=regularizers.l2(0.0005), activation='relu')) 
model.add(BatchNormalization()) 
model.add(Dense(128,kernel_regularizer=regularizers.l2(0.0005), activation='relu')) 
model.add(Dropout(0.3)) 
model.add(Dense(10, activation='softmax')) 

model.summary()
# Out:
# C:\Users\420\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)                  │ (None, 58)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │          15,104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 50,314 (196.54 KB)
#  Trainable params: 49,802 (194.54 KB)
#  Non-trainable params: 512 (2.00 KB)

# %%
#Compiling & Fitting the Model
adam = keras.optimizers.Adam(learning_rate=1e-4)
model.compile(optimizer=adam, 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])
hist = model.fit(X_train, y_train, validation_data= (X_test, y_test),
                epochs=100,
                batch_size=32)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.0792 - loss: 2.9742 - val_accuracy: 0.0933 - val_loss: 2.4244
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1714 - loss: 2.5305 - val_accuracy: 0.2133 - val_loss: 2.3911
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2626 - loss: 2.2648 - val_accuracy: 0.2533 - val_loss: 2.3579
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3120 - loss: 2.1392 - val_accuracy: 0.3067 - val_loss: 2.3247
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4022 - loss: 1.9282 - val_accuracy: 0.3467 - val_loss: 2.2874
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4014 - loss: 1.8759 - val_accuracy: 0.3667 - val_loss: 2.2505
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4345 - loss: 1.8116 - val_accuracy: 0.4067 - val_loss: 2.2081
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4655 - loss: 1.6849 - val_accuracy: 0.4333 - val_loss: 2.1646
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4793 - loss: 1.6558 - val_accuracy: 0.4333 - val_loss: 2.1154
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4826 - loss: 1.5941 - val_accuracy: 0.4467 - val_loss: 2.0644
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5488 - loss: 1.4776 - val_accuracy: 0.4600 - val_loss: 2.0092
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5303 - loss: 1.5158 - val_accuracy: 0.4467 - val_loss: 1.9530
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5525 - loss: 1.4266 - val_accuracy: 0.4667 - val_loss: 1.8902
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6079 - loss: 1.3284 - val_accuracy: 0.4867 - val_loss: 1.8286
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5705 - loss: 1.3687 - val_accuracy: 0.5067 - val_loss: 1.7664
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6034 - loss: 1.2963 - val_accuracy: 0.5000 - val_loss: 1.7038
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6075 - loss: 1.3293 - val_accuracy: 0.5267 - val_loss: 1.6437
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6073 - loss: 1.2603 - val_accuracy: 0.5400 - val_loss: 1.5814
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6492 - loss: 1.1690 - val_accuracy: 0.5533 - val_loss: 1.5259
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6558 - loss: 1.1574 - val_accuracy: 0.5800 - val_loss: 1.4743
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6575 - loss: 1.1373 - val_accuracy: 0.5867 - val_loss: 1.4263
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6485 - loss: 1.1668 - val_accuracy: 0.5933 - val_loss: 1.3823
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6717 - loss: 1.1824 - val_accuracy: 0.5867 - val_loss: 1.3444
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6625 - loss: 1.1303 - val_accuracy: 0.6133 - val_loss: 1.3211
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7078 - loss: 1.0886 - val_accuracy: 0.6267 - val_loss: 1.2854
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7089 - loss: 1.0077 - val_accuracy: 0.6333 - val_loss: 1.2548
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7260 - loss: 1.0187 - val_accuracy: 0.6400 - val_loss: 1.2290
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6899 - loss: 1.0534 - val_accuracy: 0.6333 - val_loss: 1.2123
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7058 - loss: 1.0260 - val_accuracy: 0.6333 - val_loss: 1.1898
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6968 - loss: 1.0302 - val_accuracy: 0.6400 - val_loss: 1.1761
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7580 - loss: 0.9674 - val_accuracy: 0.6400 - val_loss: 1.1643
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7528 - loss: 0.9626 - val_accuracy: 0.6400 - val_loss: 1.1469
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7566 - loss: 0.9362 - val_accuracy: 0.6533 - val_loss: 1.1412
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7415 - loss: 0.9594 - val_accuracy: 0.6600 - val_loss: 1.1325
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8835 - loss: 0.5647 - val_accuracy: 0.7133 - val_loss: 0.9916
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8770 - loss: 0.5897 - val_accuracy: 0.6933 - val_loss: 0.9993
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8857 - loss: 0.5628 - val_accuracy: 0.7000 - val_loss: 0.9884
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8907 - loss: 0.5653 - val_accuracy: 0.7133 - val_loss: 0.9862
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8839 - loss: 0.5612 - val_accuracy: 0.7000 - val_loss: 0.9873
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8885 - loss: 0.5121 - val_accuracy: 0.7133 - val_loss: 0.9930
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8742 - loss: 0.5593 - val_accuracy: 0.7133 - val_loss: 0.9977
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8778 - loss: 0.5468 - val_accuracy: 0.7267 - val_loss: 0.9891
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8934 - loss: 0.5146 - val_accuracy: 0.7267 - val_loss: 0.9777
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8587 - loss: 0.5460 - val_accuracy: 0.7200 - val_loss: 0.9801
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9073 - loss: 0.5268 - val_accuracy: 0.7267 - val_loss: 0.9825
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9040 - loss: 0.5133 - val_accuracy: 0.7267 - val_loss: 0.9838
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8987 - loss: 0.5443 - val_accuracy: 0.7400 - val_loss: 0.9856
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8954 - loss: 0.5265 - val_accuracy: 0.7200 - val_loss: 0.9790
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9190 - loss: 0.4774 - val_accuracy: 0.7267 - val_loss: 0.9694
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9098 - loss: 0.4565 - val_accuracy: 0.7467 - val_loss: 0.9659
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8916 - loss: 0.5038 - val_accuracy: 0.7267 - val_loss: 0.9727
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8936 - loss: 0.4886 - val_accuracy: 0.7200 - val_loss: 0.9800
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8797 - loss: 0.4974 - val_accuracy: 0.7333 - val_loss: 0.9685
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8882 - loss: 0.5032 - val_accuracy: 0.7467 - val_loss: 0.9731
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9051 - loss: 0.4744 - val_accuracy: 0.7333 - val_loss: 0.9814
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9142 - loss: 0.4766 - val_accuracy: 0.7400 - val_loss: 0.9775
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9047 - loss: 0.4856 - val_accuracy: 0.7533 - val_loss: 0.9785
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9138 - loss: 0.4660 - val_accuracy: 0.7333 - val_loss: 0.9815
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9225 - loss: 0.4253 - val_accuracy: 0.7267 - val_loss: 0.9793
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9341 - loss: 0.4280 - val_accuracy: 0.7333 - val_loss: 0.9787
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9391 - loss: 0.4095 - val_accuracy: 0.7400 - val_loss: 0.9812

# %% [markdown]
# Test set:

# %%
y_predict = np.argmax(model.predict(X_test),axis=1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
acc = np.mean(y_predict == y_test)*100
print("test accuracy = %.2f"%acc, "%");
# Out:
# test accuracy = 74.00 %

# %% [markdown]
# Plot scores:

# %%
fig, axs = plt.subplots(2, figsize=(10, 10))

#Accuracy
axs[0].plot(hist.history['accuracy'], label="train")
axs[0].plot(hist.history['val_loss'], label="test")
axs[0].set_ylabel("Accuracy")
axs[0].legend()
axs[0].set_title("Accuracy")
axs[0].grid()

#Error
axs[1].plot(hist.history["loss"], label="train") 
axs[1].plot(hist.history["val_loss"], label="test")     
axs[1].set_ylabel("Error") 
axs[1].legend() 
axs[1].set_title("Error") 
axs[1].grid()

plt.show()

# %% [markdown]
# #### Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_predict);

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues", values_format="d")

plt.title('Confusion Matrix')
plt.show()
